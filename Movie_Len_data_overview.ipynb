# %% [markdown]
# ## Author: Tao Shan
# ## Description:
# Data Generation for metadata, posters, movie descriptions for TMDB movie dataset by API.
#
# ## API documentation:
# https://grouplens.org/datasets/movielens/25m/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DIR_PATH = "/content/drive/MyDrive/cs680 final project/MovieLen_25M_data"

# %%
import os
import sys
import pandas as pd
import numpy as np

# %%
df_scores = pd.read_csv(
    os.path.join(DIR_PATH, f"genome-scores.csv")
)
df_scores.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02875
# 1        1      2    0.02375
# 2        1      3    0.06250
# 3        1      4    0.07575
# 4        1      5    0.14075

# %%
df_genome_tags = pd.read_csv(
    os.path.join(DIR_PATH, f"genome-tags.csv")
)
df_genome_tags.head()
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
df_links = pd.read_csv(
    os.path.join(DIR_PATH, f"links.csv")
)
df_links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %% [markdown]
# the links dataset which knows which ID is in tmdb dataset

# %%
df_movies = pd.read_csv(
    os.path.join(DIR_PATH, f"movies.csv")
)
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_ratings = pd.read_csv(
    os.path.join(DIR_PATH, f"ratings.csv")
)
df_ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
df_ratings.shape
# Out:
# (25000095, 4)

# %%
df_ratings['userId'].nunique()
# Out:
# 162541

# %%
df_tags = pd.read_csv(
    os.path.join(DIR_PATH, f"tags.csv")
)
df_tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455
